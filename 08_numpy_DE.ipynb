# %% [markdown]
# # Übung zu NumPy und pandas

# %% [markdown]
# Hier sind einige Aufgaben für dich, um das aufzufrischen, was du in den Notebooks zuvor gesehen hast.
#
# Es wird dir helfen, die **Lernziele** aus dem vorherigen Notebook zu festigen. Du solltest in der Lage sein
# - NumPy arrays zu erstellen
# - sie mit grundlegenden mathematischen Operatoren zu manipulieren
# - Zeilen, Spalten und Elemente durch Indizierung zu extrahieren
# - Aggregationsmethoden (wie sum, min, max, std) auf NumPy arrays zu verwenden

# %% [markdown]
# ## Teil 1: NumPy arrays erstellen.

# %% [markdown]
# 1. Bitte erstelle ein NumPy array aus der Liste:
# ```Python
# my_list = [1, 2, 5, 6, 8]
# ````
#
# - Bitte erstelle ein numpy array, das die Werte von 1 bis 10 enthält.
# - Bitte erstelle ein numpy array von 0 bis 5 mit einer Schrittweite von 0,2
# - Erstelle ein numpy array mit der Form 2,3 mit Zufallswerten

# %% [markdown]
# 2. Bitte erstelle ein NumPy array, das die Werte von 1 bis 10 enthält.

# %% [markdown]
# 3. Bitte erstelle ein NumPy array von 0 bis 5 mit einer Schrittweite von 0,2

# %% [markdown]
# 4. Erstelle ein NumPy array mit der Form 2,3 mit Zufallswerten

# %% [markdown]
# ## Teil 2: NumPy arrays manipulieren.

# %% [markdown]
# 1. Bitte erstelle ein NumPy array mit (1, 3, '4', 7, 12, '0'). Definiere den Inhalt als Integer.

# %% [markdown]
# 2. Überprüfe den Datentyp der Objekte und die Form des Arrays

# %% [markdown]
# 3. Aktualisiere den 4. Wert auf 30.

# %% [markdown]
# 4. Forme das Array in eine 2x3-Matrix um.

# %% [markdown]
# 5. Bitte addiere 8 zu jedem Wert in der ersten Zeile und 12 zu jedem in der zweiten Zeile.

# %% [markdown]
# 6. Multipliziere die erste Spalte mit 2, die zweite mit 3 und die dritte mit 4.

# %% [markdown]
# 7. Bitte summiere alle Zahlen in der ersten Zeile und alle Zahlen in der zweiten Zeile.

# %% [markdown]
# 8. Suche ähnlich die größte Zahl für jede Spalte.

# %% [markdown]
# 9. Extrahiere die Zahl in der zweiten Spalte und der ersten Zeile.

# %% [markdown]
# 10. Überprüfe, bei welchem Index der Wert genau 48 ist.
